# %%
import pandas as pd
from sqlalchemy import create_engine

import matplotlib.pyplot as plt
import numpy as np
#import pymysql
#pymysql.install_as_MySQldb()
# %matplotlib inline

# %% [markdown]
# ### Store CSV into DataFrame

# %%
csv_file = "../Resources/Womens_GrandSlam.csv"
womens_df = pd.read_csv(csv_file)
womens_df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-ed69401f973f> in <module>
#       1 csv_file = "../Resources/Womens_GrandSlam.csv"
# ----> 2 womens_df = pd.read_csv(csv_file)
#       3 womens_df.head()
#
# /anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# --> 678         return _read(filepath_or_buffer, kwds)
#     679
#     680     parser_f.__name__ = name
#
# /anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     438
#     439     # Create the parser.
# --> 440     parser = TextFileReader(filepath_or_buffer, **kwds)
#     441
#     442     if chunksize or iterator:
#
# /anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     785             self.options['has_index_names'] = kwds['has_index_names']
#     786
# --> 787         self._make_engine(self.engine)
#     788
#     789     def close(self):
#
# /anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1012     def _make_engine(self, engine='c'):
#    1013         if engine == 'c':
# -> 1014             self._engine = CParserWrapper(self.f, **self.options)
#    1015         else:
#    1016             if engine == 'python':
#
# /anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1706         kwds['usecols'] = self.usecols
#    1707
# -> 1708         self._reader = parsers.TextReader(src, **kwds)
#    1709
#    1710         passed_names = self.names is None
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: File b'../Resources/Womens_GrandSlam.csv' does not exist

# %% [markdown]
# ### Create new data with select columns

# %%
womens_grand_slam_df = womens_df[['Year', 'Major', 'Champion']].copy()
womens_grand_slam_df.head()
# Out:
#    Year  Major          Champion
# 0  1968      2      Nancy Richey
# 1  1968      3  Billie Jean King
# 2  1968      4     Virginia Wade
# 3  1969      1    Margaret Court
# 4  1969      2    Margaret Court

# %%
csv_file = "../Resources/Mens_GrandSlam.csv"
mens_grand_slam_df = pd.read_csv(csv_file)
mens_grand_slam_df.head()
# Out:
#    Year  Major#      Champion  Seed_Champion Ctry_Champion      Runner-up  \
# 0  1968       2  Ken Rosewall              2           AUS      Rod Laver
# 1  1968       3     Rod Laver              1           AUS     Tony Roche
# 2  1968       4   Arthur Ashe              5           USA      Tom Okker
# 3  1969       1     Rod Laver              1           AUS  Andrés Gimeno
# 4  1969       2     Rod Laver              1           AUS   Ken Rosewall
#
#    Seed_Runner-up Ctry_Runner-up         Score in the Final
# 0               1            AUS         6–3, 6–1, 2–6, 6–2
# 1              15            AUS              6–3, 6–4, 6–2
# 2               8            NED  14–12, 5–7, 6–3, 3–6, 6–3
# 3               9            ESP              6–3, 6–4, 7–5
# 4               4            AUS              6–4, 6–3, 6–4

# %%
mens_grand_slam_df.rename(columns={'Major#': 'Major'}, inplace=True)
mens_grand_slam_df.head()
# Out:
#    Year  Major      Champion  Seed_Champion Ctry_Champion      Runner-up  \
# 0  1968      2  Ken Rosewall              2           AUS      Rod Laver
# 1  1968      3     Rod Laver              1           AUS     Tony Roche
# 2  1968      4   Arthur Ashe              5           USA      Tom Okker
# 3  1969      1     Rod Laver              1           AUS  Andrés Gimeno
# 4  1969      2     Rod Laver              1           AUS   Ken Rosewall
#
#    Seed_Runner-up Ctry_Runner-up         Score in the Final
# 0               1            AUS         6–3, 6–1, 2–6, 6–2
# 1              15            AUS              6–3, 6–4, 6–2
# 2               8            NED  14–12, 5–7, 6–3, 3–6, 6–3
# 3               9            ESP              6–3, 6–4, 7–5
# 4               4            AUS              6–4, 6–3, 6–4

# %%
# mens_grand_slam_df = mens_df[['Year', 'Major#', 'Champion']].copy()
# mens_grand_slam_df.head()

# %% [markdown]
# ### Connect to local database

# %%
#rds_connection_string = "<insert user name>:<insert password>@localhost:5432/customer_db"
database_path = "../Resources/tennis.sqlite"
engine = create_engine(f"sqlite:///{database_path}")

# %% [markdown]
# ### Check for tables

# %%
engine.table_names()
# Out:
# ['men_champion', 'women_champion']

# %% [markdown]
# ### Use pandas to load csv converted DataFrame into database

# %%
womens_grand_slam_df.to_sql(name='Womens', con=engine, if_exists='replace', index=False)
engine.table_names()
# Out:
# ['Womens', 'men_champion', 'women_champion']

# %%
mens_grand_slam_df.to_sql(name='Mens', con=engine, if_exists='replace', index=False)
engine.table_names()
# Out:
# ['Mens', 'Womens', 'men_champion', 'women_champion']

# %%
Mens_Womens_Champion_df = mens_grand_slam_df.merge(womens_grand_slam_df, how='outer', on=['Year', 'Major'], suffixes=('_Mens', '_Womens'))
Mens_Womens_Champion_df.head()
Mens_Womens_Champion_df.to_sql(name = 'GrandSlamChamps', con = engine, if_exists = 'replace', index=False)

# %% [markdown]
# ### Confirm data has been added by querying the customer_name table
# * NOTE: can also check using pgAdmin

# %%
pd.read_sql_query('select * from Womens ', con=engine).head()
# Out:
#    Year  Major          Champion
# 0  1968      2      Nancy Richey
# 1  1968      3  Billie Jean King
# 2  1968      4     Virginia Wade
# 3  1969      1    Margaret Court
# 4  1969      2    Margaret Court

# %%
pd.read_sql_query('select * from Mens ', con=engine).head()
# Out:
#    Year  Major      Champion  Seed_Champion Ctry_Champion      Runner-up  \
# 0  1968      2  Ken Rosewall              2           AUS      Rod Laver
# 1  1968      3     Rod Laver              1           AUS     Tony Roche
# 2  1968      4   Arthur Ashe              5           USA      Tom Okker
# 3  1969      1     Rod Laver              1           AUS  Andrés Gimeno
# 4  1969      2     Rod Laver              1           AUS   Ken Rosewall
#
#    Seed_Runner-up Ctry_Runner-up         Score in the Final
# 0               1            AUS         6–3, 6–1, 2–6, 6–2
# 1              15            AUS              6–3, 6–4, 6–2
# 2               8            NED  14–12, 5–7, 6–3, 3–6, 6–3
# 3               9            ESP              6–3, 6–4, 7–5
# 4               4            AUS              6–4, 6–3, 6–4

# %% [markdown]
# ### Confirm data has been added by querying the customer_location table

# %%
pd.read_sql_query('select * from Womens', con=engine).head()
# Out:
#    Year  Major          Champion
# 0  1968      2      Nancy Richey
# 1  1968      3  Billie Jean King
# 2  1968      4     Virginia Wade
# 3  1969      1    Margaret Court
# 4  1969      2    Margaret Court

# %%
pd.read_sql_query('select * from Mens', con=engine).head()
# Out:
#    Year  Major      Champion  Seed_Champion Ctry_Champion      Runner-up  \
# 0  1968      2  Ken Rosewall              2           AUS      Rod Laver
# 1  1968      3     Rod Laver              1           AUS     Tony Roche
# 2  1968      4   Arthur Ashe              5           USA      Tom Okker
# 3  1969      1     Rod Laver              1           AUS  Andrés Gimeno
# 4  1969      2     Rod Laver              1           AUS   Ken Rosewall
#
#    Seed_Runner-up Ctry_Runner-up         Score in the Final
# 0               1            AUS         6–3, 6–1, 2–6, 6–2
# 1              15            AUS              6–3, 6–4, 6–2
# 2               8            NED  14–12, 5–7, 6–3, 3–6, 6–3
# 3               9            ESP              6–3, 6–4, 7–5
# 4               4            AUS              6–4, 6–3, 6–4

# %%
#pd.read_sql_query('select * from Mens join Womens on Mens.Year = Womens.Year', con=engine).head(20)

#select film.film_id, film.title, count(film_actor.actor_id)
#from film
#inner join film_actor on film.film_id = film_actor.film_id
#group by film.film_id;

# %%
pd.read_sql_query('select * from GrandSlamChamps ', con=engine).head(20)
# Out:
#     Year  Major  Champion_Mens  Seed_Champion Ctry_Champion  \
# 0   1968      2   Ken Rosewall              2           AUS
# 1   1968      3      Rod Laver              1           AUS
# 2   1968      4    Arthur Ashe              5           USA
# 3   1969      1      Rod Laver              1           AUS
# 4   1969      2      Rod Laver              1           AUS
# 5   1969      3      Rod Laver              1           AUS
# 6   1969      4      Rod Laver              1           AUS
# 7   1970      1    Arthur Ashe              4           USA
# 8   1970      2      Jan Kodeš              7           TCH
# 9   1970      3  John Newcombe              2           AUS
# 10  1970      4   Ken Rosewall              3           AUS
# 11  1971      1   Ken Rosewall              2           AUS
# 12  1971      2      Jan Kodeš              1           TCH
# 13  1971      3  John Newcombe              2           AUS
# 14  1971      4     Stan Smith              2           USA
# 15  1972      1   Ken Rosewall              2           AUS
# 16  1972      2  Andrés Gimeno              6           ESP
# 17  1972      3     Stan Smith              1           USA
# 18  1972      4   Ilie Năstase              4           ROU
# 19  1973      1  John Newcombe              2           AUS
#
#             Runner-up  Seed_Runner-up Ctry_Runner-up  \
# 0           Rod Laver               1            AUS
# 1          Tony Roche              15            AUS
# 2           Tom Okker               8            NED
# 3       Andrés Gimeno               9            ESP
# 4        Ken Rosewall               4            AUS
# 5       John Newcombe               6            AUS
# 6          Tony Roche               3            AUS
# 7         Dick Crealy              12            AUS
# 8   Željko Franulović               5            YUG
# 9        Ken Rosewall               5            AUS
# 10         Tony Roche               4            AUS
# 11        Arthur Ashe               3            USA
# 12       Ilie Năstase               3            ROU
# 13         Stan Smith               4            USA
# 14          Jan Kodeš               0            TCH
# 15   Malcolm Anderson               8            AUS
# 16     Patrick Proisy               9            FRA
# 17       Ilie Năstase               2            ROM
# 18        Arthur Ashe               6            USA
# 19         Onny Parun              12            NZL
#
#               Score in the Final   Champion_Womens
# 0             6–3, 6–1, 2–6, 6–2      Nancy Richey
# 1                  6–3, 6–4, 6–2  Billie Jean King
# 2      14–12, 5–7, 6–3, 3–6, 6–3     Virginia Wade
# 3                  6–3, 6–4, 7–5    Margaret Court
# 4                  6–4, 6–3, 6–4    Margaret Court
# 5             6–4, 5–7, 6–4, 6–4         Ann Jones
# 6             7–9, 6–1, 6–2, 6–2    Margaret Court
# 7                  6–4, 9–7, 6–2    Margaret Court
# 8                  6–2, 6–4, 6–0    Margaret Court
# 9        5–7, 6–3, 6–2, 3–6, 6–1    Margaret Court
# 10       2–6, 6–4, 7–6(5–2), 6–3    Margaret Court
# 11                 6–1, 7–5, 6–3    Margaret Court
# 12            8–6, 6–2, 2–6, 7–5  Evonne Goolagong
# 13       6–3, 5–7, 2–6, 6–4, 6–4  Evonne Goolagong
# 14       3–6, 6–3, 6–2, 7–6(5–3)  Billie Jean King
# 15            7–6(7–2), 6–3, 7–5     Virginia Wade
# 16            4–6, 6–3, 6–1, 6–1  Billie Jean King
# 17       4–6, 6–3, 6–3, 4–6, 7–5  Billie Jean King
# 18  3–6, 6–3, 6–7(1–5), 6–4, 6–3  Billie Jean King
# 19            6–3, 6–7, 7–5, 6–1    Margaret Court

# %%
#Mens_Womens_Champ_Results_df = pd.read_sql_query("select Champion_Mens, count(Champion_Mens), Champion_Womens, count(Champion_Womens) from GrandSlamChamps group by Champion_Mens, Champion_Womens", con=engine)
#Mens_Womens_Champ_Results_df.head()

# %%
Womens_Champ_Results_df = pd.read_sql_query("select Champion_Womens, count(Champion_Womens) from GrandSlamChamps group by Champion_Womens", con=engine)
Womens_Champ_Results_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-26fb3871369f> in <module>
# ----> 1 Womens_Champ_Results_df = pd.read_sql_query("select Champion_Womens, count(Champion_Womens) from GrandSlamChamps group by Champion_Womens", con=engine)
#       2 Womens_Champ_Results_df.head()
#
# NameError: name 'pd' is not defined

# %%
names_only = Womens_Champ_Results_df.Champion_Womens
names_only.head()

#cnt_only = Womens_Champ_Results_df[1]
#cnt_only.head()
#= pd.read_sql_query("select Champion_Womens, count(Champion_Womens) from GrandSlamChamps group by Champion_Womens", con=engine)
# Out:
# 0      Amélie Mauresmo
# 1         Ana Ivanovic
# 2    Anastasia Myskina
# 3     Angelique Kerber
# 4            Ann Jones
# Name: Champion_Womens, dtype: object

# %%
pd.read_sql_query("select Champion_Mens, count(Champion_Mens) from GrandSlamChamps group by Champion_Mens", con=engine)
# Out:
#           Champion_Mens  count(Champion_Mens)
# 0       Adriano Panatta                     1
# 1          Albert Costa                     1
# 2          Andre Agassi                     8
# 3         Andrés Gimeno                     1
# 4          Andrés Gómez                     1
# 5           Andy Murray                     3
# 6          Andy Roddick                     1
# 7           Arthur Ashe                     3
# 8            Björn Borg                    11
# 9          Boris Becker                     6
# 10        Brian Teacher                     1
# 11          Carlos Moyá                     1
# 12        Gastón Gaudio                     1
# 13     Goran Ivanišević                     1
# 14      Guillermo Vilas                     4
# 15      Gustavo Kuerten                     3
# 16         Ilie Năstase                     2
# 17           Ivan Lendl                     8
# 18            Jan Kodeš                     3
# 19          Jim Courier                     4
# 20        Jimmy Connors                     8
# 21          Johan Kriek                     2
# 22         John McEnroe                     7
# 23        John Newcombe                     5
# 24  Juan Carlos Ferrero                     1
# 25    Juan Martin Potro                     1
# 26         Ken Rosewall                     4
# 27       Lleyton Hewitt                     2
# 28       Manuel Orantes                     1
# 29          Marat Safin                     2
# 30          Marin Čilić                     1
# 31       Mark Edmondson                     1
# 32        Mats Wilander                     7
# 33        Michael Chang                     1
# 34        Michael Stich                     1
# 35       Novak Djokovic                    14
# 36             Pat Cash                     1
# 37       Patrick Rafter                     2
# 38         Pete Sampras                    14
# 39           Petr Korda                     1
# 40         Rafael Nadal                    17
# 41     Richard Krajicek                     1
# 42            Rod Laver                     5
# 43        Roger Federer                    20
# 44        Roscoe Tanner                     2
# 45       Sergi Bruguera                     2
# 46           Stan Smith                     2
# 47        Stan Wawrinka                     3
# 48        Stefan Edberg                     6
# 49     Thomas Johansson                     1
# 50        Thomas Muster                     1
# 51     Vitas Gerulaitis                     2
# 52         Yannick Noah                     1
# 53   Yevgeny Kafelnikov                     2

# %%
Mens_Champ_Results_df = pd.read_sql_query("select Champion_Mens, count(Champion_Mens)from GrandSlamChamps group by Champion_Mens", con=engine)
Mens_Champ_Results_df
# Out:
#           Champion_Mens  count(Champion_Mens)
# 0       Adriano Panatta                     1
# 1          Albert Costa                     1
# 2          Andre Agassi                     8
# 3         Andrés Gimeno                     1
# 4          Andrés Gómez                     1
# 5           Andy Murray                     3
# 6          Andy Roddick                     1
# 7           Arthur Ashe                     3
# 8            Björn Borg                    11
# 9          Boris Becker                     6
# 10        Brian Teacher                     1
# 11          Carlos Moyá                     1
# 12        Gastón Gaudio                     1
# 13     Goran Ivanišević                     1
# 14      Guillermo Vilas                     4
# 15      Gustavo Kuerten                     3
# 16         Ilie Năstase                     2
# 17           Ivan Lendl                     8
# 18            Jan Kodeš                     3
# 19          Jim Courier                     4
# 20        Jimmy Connors                     8
# 21          Johan Kriek                     2
# 22         John McEnroe                     7
# 23        John Newcombe                     5
# 24  Juan Carlos Ferrero                     1
# 25    Juan Martin Potro                     1
# 26         Ken Rosewall                     4
# 27       Lleyton Hewitt                     2
# 28       Manuel Orantes                     1
# 29          Marat Safin                     2
# 30          Marin Čilić                     1
# 31       Mark Edmondson                     1
# 32        Mats Wilander                     7
# 33        Michael Chang                     1
# 34        Michael Stich                     1
# 35       Novak Djokovic                    14
# 36             Pat Cash                     1
# 37       Patrick Rafter                     2
# 38         Pete Sampras                    14
# 39           Petr Korda                     1
# 40         Rafael Nadal                    17
# 41     Richard Krajicek                     1
# 42            Rod Laver                     5
# 43        Roger Federer                    20
# 44        Roscoe Tanner                     2
# 45       Sergi Bruguera                     2
# 46           Stan Smith                     2
# 47        Stan Wawrinka                     3
# 48        Stefan Edberg                     6
# 49     Thomas Johansson                     1
# 50        Thomas Muster                     1
# 51     Vitas Gerulaitis                     2
# 52         Yannick Noah                     1
# 53   Yevgeny Kafelnikov                     2

# %%
plot_women_DF = Womens_Champ_Results_df.transpose()
plot_women_DF.head()
# Out:
#                                      0             1                  2   \
# Champion_Womens         Amélie Mauresmo  Ana Ivanovic  Anastasia Myskina
# count(Champion_Womens)                2             1                  1
#
#                                       3          4                        5   \
# Champion_Womens         Angelique Kerber  Ann Jones  Arantxa Sánchez Vicario
# count(Champion_Womens)                 3          1                        4
#
#                                     6                 7                   8   \
# Champion_Womens         Barbara Jordan  Billie Jean King  Carolina Wozniacki
# count(Champion_Womens)               1                 8                   1
#
#                                  9       ...                  42  \
# Champion_Womens         Chris Evert      ...        Simona Halep
# count(Champion_Womens)           17      ...                   1
#
#                                      43           44          45  \
# Champion_Womens         Sloane Stephens  Steffi Graf  Sue Barker
# count(Champion_Womens)                1           22           1
#
#                                          46            47              48  \
# Champion_Womens         Svetlana Kuznetsova  Tracy Austin  Venus Williams
# count(Champion_Womens)                    2             2               7
#
#                                        49               50             51
# Champion_Womens         Victoria Azarenka  Virginia Ruzici  Virginia Wade
# count(Champion_Womens)                  2                1              3
#
# [2 rows x 52 columns]

# %%
fig = plt.figure(figsize=(100,60))
Womens_Champ_Results_df.plot(kind='bar', x ='Champion_Womens', y ='count(Champion_Womens)' )
plt.show(fig)

# %%
Mens_Champ_Results_df = pd.read_sql_query("select Champion_Mens, count(Champion_Mens)from GrandSlamChamps group by Champion_Mens", con=engine)
Mens_Champ_Results_df
# Out:
#           Champion_Mens  count(Champion_Mens)
# 0       Adriano Panatta                     1
# 1          Albert Costa                     1
# 2          Andre Agassi                     8
# 3         Andrés Gimeno                     1
# 4          Andrés Gómez                     1
# 5           Andy Murray                     3
# 6          Andy Roddick                     1
# 7           Arthur Ashe                     3
# 8            Björn Borg                    11
# 9          Boris Becker                     6
# 10        Brian Teacher                     1
# 11          Carlos Moyá                     1
# 12        Gastón Gaudio                     1
# 13     Goran Ivanišević                     1
# 14      Guillermo Vilas                     4
# 15      Gustavo Kuerten                     3
# 16         Ilie Năstase                     2
# 17           Ivan Lendl                     8
# 18            Jan Kodeš                     3
# 19          Jim Courier                     4
# 20        Jimmy Connors                     8
# 21          Johan Kriek                     2
# 22         John McEnroe                     7
# 23        John Newcombe                     5
# 24  Juan Carlos Ferrero                     1
# 25    Juan Martin Potro                     1
# 26         Ken Rosewall                     4
# 27       Lleyton Hewitt                     2
# 28       Manuel Orantes                     1
# 29          Marat Safin                     2
# 30          Marin Čilić                     1
# 31       Mark Edmondson                     1
# 32        Mats Wilander                     7
# 33        Michael Chang                     1
# 34        Michael Stich                     1
# 35       Novak Djokovic                    14
# 36             Pat Cash                     1
# 37       Patrick Rafter                     2
# 38         Pete Sampras                    14
# 39           Petr Korda                     1
# 40         Rafael Nadal                    17
# 41     Richard Krajicek                     1
# 42            Rod Laver                     5
# 43        Roger Federer                    20
# 44        Roscoe Tanner                     2
# 45       Sergi Bruguera                     2
# 46           Stan Smith                     2
# 47        Stan Wawrinka                     3
# 48        Stefan Edberg                     6
# 49     Thomas Johansson                     1
# 50        Thomas Muster                     1
# 51     Vitas Gerulaitis                     2
# 52         Yannick Noah                     1
# 53   Yevgeny Kafelnikov                     2

# %%
plot_mens_DF = Mens_Champ_Results_df.transpose()
plot_mens_DF.head()
# Out:
#                                    0             1             2   \
# Champion_Mens         Adriano Panatta  Albert Costa  Andre Agassi
# count(Champion_Mens)                1             1             8
#
#                                  3             4            5             6   \
# Champion_Mens         Andrés Gimeno  Andrés Gómez  Andy Murray  Andy Roddick
# count(Champion_Mens)              1             1            3             1
#
#                                7           8             9   \
# Champion_Mens         Arthur Ashe  Björn Borg  Boris Becker
# count(Champion_Mens)            3          11             6
#
#                              ...                     44              45  \
# Champion_Mens                ...          Roscoe Tanner  Sergi Bruguera
# count(Champion_Mens)         ...                      2               2
#
#                               46             47             48  \
# Champion_Mens         Stan Smith  Stan Wawrinka  Stefan Edberg
# count(Champion_Mens)           2              3              6
#
#                                     49             50                51  \
# Champion_Mens         Thomas Johansson  Thomas Muster  Vitas Gerulaitis
# count(Champion_Mens)                 1              1                 2
#
#                                 52                  53
# Champion_Mens         Yannick Noah  Yevgeny Kafelnikov
# count(Champion_Mens)             1                   2
#
# [2 rows x 54 columns]

# %%
fig = plt.figure(figsize=(100,60))
Womens_Champ_Results_df.plot(kind='bar', x ='Champion_Womens', y ='count(Champion_Womens)' )
plt.show(fig)

# %%
fig = plt.figure(figsize=(100,60))
Mens_Champ_Results_df.plot(kind='bar', x ='Champion_Mens', y ='count(Champion_Mens)' )
plt.show(fig)
